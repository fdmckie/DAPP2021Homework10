# %% [markdown]
# # Module 2 Exercises

# %% [markdown]
# #### 1. Import the <b>two</b> libraries you need to work with datasets and use mathmatical functions.

# %%
#import the pandas & numpy Python libraries...
#import ------ as --
#import ----- as --

import pandas as pd
import numpy as np

# %% [markdown]
# #### 2. Import the <b>titanic.xls</b> file and store the dataset in a variable named: <b>titanic</b>. This dataset includes information about the passengers aboard the Titanic. The dataset includes the following columns:
#
#     * pclass = passenger class; 1 = first class, 2 = second class, 3 = third class
#     * survived = passenger survival; 1 = survived, 0 = did not survive
#     * name = passenger name
#     * sex = sex of passenger
#     * age = age of passenger
#     * sibsp = # of siblings / spouses aboard the Titanic
#     * parch = # of parents / children aboard the Titanic
#     * ticket = ticket number
#     * fare = fare paid by passenger
#     * cabin = passenger cabin
#     * embarked = port of embarkation; C = Cherbourg, Q = Queenstown, S = Southampton
#     * boat = lifeboat assignment
#     * body = recovered body number
#     * home dest = anticipated home destination
#
# <b> Use the 4 cells below to write out questions you hope to answer with the titanic dataset <i><u>before</u></i> you start exploring the dataset (example: how many passengers did not survive the titanic sinking?)

# %%
#import the "titanic.xls" file/dataset into a variable named "titanic"...

titanic = pd.read_excel("datasets/titanic.xls")
titanic
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex      age  sibsp  parch  ticket      fare    cabin embarked boat  \
# ...

# %%
## Question 1: how many people survived? how many died?

# %%
## Question 2: from the people that survived & died, from which passenger class?

# %%
## Question 3: from the people that survived & died, from where they embarked the ship?

# %%
## Question 4: from the people that survived & died, the breakdown by sex?

# %% [markdown]
# #### 3. View the first 20 rows of the dataset.

# %%
# use the "head" method to view the first 20 rows of the "titanic" dataset...

titanic.head(20)
# Out:
#     pclass  survived                                               name  \
# 0        1         1                      Allen, Miss. Elisabeth Walton
# 1        1         1                     Allison, Master. Hudson Trevor
# 2        1         0                       Allison, Miss. Helen Loraine
# 3        1         0               Allison, Mr. Hudson Joshua Creighton
# 4        1         0    Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# 5        1         1                                Anderson, Mr. Harry
# 6        1         1                  Andrews, Miss. Kornelia Theodosia
# 7        1         0                             Andrews, Mr. Thomas Jr
# 8        1         1      Appleton, Mrs. Edward Dale (Charlotte Lamson)
# 9        1         0                            Artagaveytia, Mr. Ramon
# 10       1         0                             Astor, Col. John Jacob
# 11       1         1  Astor, Mrs. John Jacob (Madeleine Talmadge Force)
# ...

# %% [markdown]
# #### 4. View the last 20 rows of the dataset.

# %%
# use the "tail" method to view the last 20 rows of the "titanic" dataset...

titanic.tail(20)
# Out:
#       pclass  survived                                     name     sex   age  \
# 1289       3         0                  Wiklund, Mr. Karl Johan    male  21.0
# 1290       3         1         Wilkes, Mrs. James (Ellen Needs)  female  47.0
# 1291       3         0         Willer, Mr. Aaron ("Abi Weller")    male   NaN
# 1292       3         0                       Willey, Mr. Edward    male   NaN
# 1293       3         0        Williams, Mr. Howard Hugh "Harry"    male   NaN
# 1294       3         0                     Williams, Mr. Leslie    male  28.5
# 1295       3         0                      Windelov, Mr. Einar    male  21.0
# 1296       3         0                         Wirz, Mr. Albert    male  27.0
# 1297       3         0                   Wiseman, Mr. Phillippe    male   NaN
# 1298       3         0                Wittevrongel, Mr. Camille    male  36.0
# 1299       3         0                      Yasbeck, Mr. Antoni    male  27.0
# ...

# %% [markdown]
# #### 5. Complete the code below to find some meta information for our dataset. How many columns are there total in the dataset? In which column(s) do we have missing/NaN values?

# %%
# use the "info" method to view some meta information of/about the "titanic" dataset...

#titanic.----()

titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1309 entries, 0 to 1308
# Data columns (total 14 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   pclass     1309 non-null   int64
#  1   survived   1309 non-null   int64
#  2   name       1309 non-null   object
#  3   sex        1309 non-null   object
#  4   age        1046 non-null   float64
#  5   sibsp      1309 non-null   int64
#  6   parch      1309 non-null   int64
#  7   ticket     1309 non-null   object
#  8   fare       1308 non-null   float64
#  9   cabin      295 non-null    object
#  10  embarked   1307 non-null   object
#  11  boat       486 non-null    object
#  12  body       121 non-null    float64
#  13  home.dest  745 non-null    object
# dtypes: float64(3), int64(4), object(7)
# memory usage: 143.3+ KB

# %%
# there are 14 columns in the dataset...
# there is missing data in the "age", "fare", "cabin", "embarked", "boat", "body", & "home.dest" columns...

# %% [markdown]
# #### 6. Write the code to get summary statistics for the titanic dataset.

# %%
# use the "describe" method to view summary statistics from the "titanic" dataset...

titanic.describe()
# Out:
#             pclass     survived          age        sibsp        parch  \
# count  1309.000000  1309.000000  1046.000000  1309.000000  1309.000000
# mean      2.294882     0.381971    29.881135     0.498854     0.385027
# std       0.837836     0.486055    14.413500     1.041658     0.865560
# min       1.000000     0.000000     0.166700     0.000000     0.000000
# 25%       2.000000     0.000000    21.000000     0.000000     0.000000
# 50%       3.000000     0.000000    28.000000     0.000000     0.000000
# 75%       3.000000     1.000000    39.000000     1.000000     0.000000
# max       3.000000     1.000000    80.000000     8.000000     9.000000
#
#               fare        body
# count  1308.000000  121.000000
# mean     33.295479  160.809917
# std      51.758668   97.696922
# min       0.000000    1.000000
# 25%       7.895800   72.000000
# 50%      14.454200  155.000000
# 75%      31.275000  256.000000
# max     512.329200  328.000000

# %% [markdown]
# #### 7. Write the code <i>(without using the .info function)</i> to find the following information:
#
#     * how old was the oldest passenger on the ship?
#     * how old was the youngest passenger on the ship?
#     * what are the total ticket sales for all passengers?
#     * how many passengers embarked at each port?
#     * what is the average number of siblings/spouses that were traveling with each passenger?
#
#  Use a new cell to answer each question above.

# %%
# use the "head" method to view the names of the columns in the "titanic" dataset...

titanic.head(1)
# Out:
#    pclass  survived                           name     sex   age  sibsp  \
# 0       1         1  Allen, Miss. Elisabeth Walton  female  29.0      0
#
#    parch ticket      fare cabin embarked boat  body     home.dest
# 0      0  24160  211.3375    B5        S    2   NaN  St Louis, MO

# %%
# how old was the oldest passenger on the ship?

# use the "max" method to discover the largest value in the "age" column from the "titanic" dataset...

titanic["age"].max()
# Out:
# 80.0

# %%
# the oldest person was 80 years old...

# %%
# how old was the youngest passenger on the ship? 

# use the "min" method to discover the lowest value in the "age" column from the "titanic" dataset...

titanic["age"].min()
# Out:
# 0.1667

# %%
# the youngest person was 0.1667 years old (2 months old) (0.1667 * 12 months)...

# %%
# what are the total ticket sales for all passengers?

# use the "sum" method to discover the total of all of the values in the "fare" column from the "titanic" dataset...

titanic["fare"].sum()
# Out:
# 43550.4869

# %%
# the total ticket sales for all passengers was 43,550.4869 (43,550.49)...
# I am assuming that the payment(s) were in British pounds, since most of the passengers had boarded the ship 
# in England...
# See answer(s) to the question below!!!

# %%
# how many passengers embarked at each port?

# use the "value_counts" method to determine the number of passengers that boarded the ship in each port
# by the total(s) of the three values (ports) in the "embarked" column)...

titanic["embarked"].value_counts()
# Out:
# S    914
# C    270
# Q    123
# Name: embarked, dtype: int64

# %%
# 914 passengers embarked in Southampton (England)...
# 270 passengers embarked in Cherbourg (France)...
# 123 passengers embarked in Queenstown (England)...

# %%
# what is the average number of siblings/spouses that were traveling with each passenger?

# use the "mean" method on the "sibsp" (sibling/spouse) column in the "titanic" dataset...

titanic["sibsp"].mean()
# Out:
# 0.4988540870893812

# %%
# the average number of siblings/spouses that traveled with each passenger was 0.4988540870893812
# (about 0.5 siblings/spouses traveling with each passenger)...

# %% [markdown]
# #### 8. Create three unique <b>pivot tables</b> using the titanic data. Make one statement about something you can determine from the information each table shows.
#
# <b>EXAMPLE:</b> "The table above shows that employees use their vacation leave most frequently in December, June, and August."

# %%
# what is the average age, across male and female passengers, by passenger class?

pd.pivot_table(titanic, index=["pclass"], values=["age"], columns=["sex"])
# Out:
#               age
# sex        female       male
# pclass
# 1       37.037594  41.029250
# 2       27.499191  30.815401
# 3       22.185307  25.962273

# %%
# on average, the olders passengers, male and female, were in first class...

# %%
# what is the average chance of surviving, across male and female passengers, by passenger class?

pd.pivot_table(titanic, index=["pclass"], values=["survived"], columns=["sex"])
# Out:
#         survived
# sex       female      male
# pclass
# 1       0.965278  0.340782
# 2       0.886792  0.146199
# 3       0.490741  0.152130

# %%
# on average, the better chance of survival, male and female, was to be a first class passenger...

# %%
# what is the average age, across male and female passengers, by survival (or not)?

pd.pivot_table(titanic, index=["survived"], values=["age"], columns=["sex"])
# Out:
#                 age
# sex          female       male
# survived
# 0         25.255208  31.516412
# 1         29.815354  26.977778

# %%
# on average, the age of a female survivor was older, younger as a male, in comparison to the non-survivors...

# %% [markdown]
# #### 9. Create a crosstab (cross-tabulation table) to answer the following questions:
#
# How many women are in each of the passenger classes? How many men are in each?

# %%
# discover the number of men and women ("sex" column) in each passenger class ("pclass" column)...

pd.crosstab(titanic["pclass"], titanic["sex"])
# Out:
# sex     female  male
# pclass
# 1          144   179
# 2          106   171
# 3          216   493

# %%
# in passenger class 1, there were 144 women & 179 men...
# in passenger class 2, there were 106 women & 171 men...
# in passenger class 3, there were 216 women & 493 men...

# %% [markdown]
# #### 10. Complete the code to find the average age of passengers by survival status.

# %%
#titanic[].-------().mean()

pd.pivot_table(titanic, index=["survived"], values=["age"])
# Out:
#                 age
# survived
# 0         30.545369
# 1         28.918228

# %%
titanic["age"].groupby(titanic["survived"]).mean()
# Out:
# survived
# 0    30.545369
# 1    28.918228
# Name: age, dtype: float64

# %%
# the average age of a non-survivor was 30.545369 years (30 years, 6.5 months)
# the average age of a survivor was 28.918228 years (28 years, 11 months)

# %% [markdown]
# #### 11. Use the groupby function to determine the average age of passengers by passenger class.

# %%
# use the "groupby" function & "mean" function to determine the average (mean) age (look at "age" column) 
# of the passengers by passenger class (look at "pclass" column)...

titanic["age"].groupby(titanic["pclass"]).mean()
# Out:
# pclass
# 1    39.159918
# 2    29.506705
# 3    24.816367
# Name: age, dtype: float64

# %%
# the average (mean) age of the passengers from 1st class is 39.159918 years old (39 years, 1.919016 months)...
# the average (mean) age of the passengers from 2nd class is 29.506705 years old (29 years, 6.08046 months)...
# the average (mean) age of the passengers from 3rd class is 24.816367 years old (24 years, 9.796404 months)...

# %% [markdown]
# #### 12. Locate all the passengers who embarked at "Queenstown".

# %%
# use the "loc" method to find all of the passengers that embarked at Queenstown (look for "Q" value in the 
# "embarked" column)...

titanic.loc[titanic['embarked'] == "Q"]
# Out:
#       pclass  survived                                             name  \
# 206        1         0                      Minahan, Dr. William Edward
# 207        1         1                           Minahan, Miss. Daisy E
# 208        1         1  Minahan, Mrs. William Edward (Lillian E Thorpe)
# 469        2         1                              Keane, Miss. Nora A
# 470        2         0                                Keane, Mr. Daniel
# ...      ...       ...                                              ...
# 1195       3         0                         Shaughnessy, Mr. Patrick
# 1198       3         1                       Shine, Miss. Ellen Natalia
# 1215       3         0                                Smith, Mr. Thomas
# 1216       3         1                               Smyth, Miss. Julia
# 1249       3         0                                 Tobin, Mr. Roger
#
#          sex   age  sibsp  parch  ticket     fare cabin embarked boat   body  \
# ...

# %%
# 123 passengers embarked at Queenstown...

# %% [markdown]
# #### 13. Locate the teenagers who were onboard the Titanic - passengers ages 13 to 19.

# %%
# using the "and" logical operator & the "loc" method, look at the "age" column to find the rows with teenagers 
# (at least age 13 & less than age 20)...

titanic.loc[(titanic["age"] >= 13.0) & (titanic["age"] < 20.0)]
# Out:
#       pclass  survived                                               name  \
# 11         1         1  Astor, Mrs. John Jacob (Madeleine Talmadge Force)
# 27         1         1            Bishop, Mrs. Dickinson H (Helen Walton)
# 53         1         0                             Carrau, Mr. Jose Pedro
# 55         1         1                          Carter, Miss. Lucile Polk
# 92         1         1          Dick, Mrs. Albert Adrian (Vera Gillespie)
# ...      ...       ...                                                ...
# 1275       3         0                    Vander Planke, Mr. Leo Edmondus
# 1279       3         0               Vestrom, Miss. Hulda Amanda Adolfina
# 1288       3         0                          Wiklund, Mr. Jakob Alfred
# 1300       3         1            Yasbeck, Mrs. Antoni (Selini Alexander)
# 1304       3         0                               Zabour, Miss. Hileni
#
#          sex   age  sibsp  parch    ticket      fare    cabin embarked boat  \
# ...

# %%
# 131 passengers were teenagers

# %% [markdown]
# #### 14. Locate the passengers who were <i>either</i> in second or third class.

# %%
# using the "or" logical operator & the "loc" method, look at the "pclass" column to find all of the 
# 2nd & 3rd class passengers...


titanic.loc[(titanic["pclass"] == 2) | (titanic["pclass"] == 3)]
# Out:
#       pclass  survived                                   name     sex   age  \
# 323        2         0                    Abelson, Mr. Samuel    male  30.0
# 324        2         1  Abelson, Mrs. Samuel (Hannah Wizosky)  female  28.0
# 325        2         0         Aldworth, Mr. Charles Augustus    male  30.0
# 326        2         0             Andrew, Mr. Edgardo Samuel    male  18.0
# 327        2         0               Andrew, Mr. Frank Thomas    male  25.0
# ...      ...       ...                                    ...     ...   ...
# 1304       3         0                   Zabour, Miss. Hileni  female  14.5
# 1305       3         0                  Zabour, Miss. Thamine  female   NaN
# 1306       3         0              Zakarian, Mr. Mapriededer    male  26.5
# 1307       3         0                    Zakarian, Mr. Ortin    male  27.0
# 1308       3         0                     Zimmerman, Mr. Leo    male  29.0
#
# ...

# %%
# 986 passengers were in 2nd class or 3rd class...

# %% [markdown]
# #### 15. Complete the code below to determine which variables have missing data.

# %%
# use the "isnull" method to find missing data in the "titanic" dataset...
# also, use the "sum" method to total the amount of missing data in each column in the "titanic" dataset...

#titanic.-----().---()

titanic.isnull().sum()
# Out:
# pclass          0
# survived        0
# name            0
# sex             0
# age           263
# sibsp           0
# parch           0
# ticket          0
# fare            1
# cabin        1014
# embarked        2
# boat          823
# body         1188
# home.dest     564
# dtype: int64

# %%
# columns "age" (263 count), "fare" (1 count), "cabin" (1014 count), "embarked" (2 count), "boat" (823 count), 
# "body" (1188 count), & "home.dest" (564 count) have missing data/information...

# %% [markdown]
# #### 16. Does the titanic dataset have any duplicate rows? Write the code to check!

# %%
# use the "duplicated" method to find rows in the "titanic" dataset that have completely identical information
# and store those rows into a variable

titanic_dupe = titanic.duplicated()


# use 'loc' to display which specific rows that have duplicate data
# if nothing is displayed, there aren't any duplicates 

titanic.loc[titanic_dupe]
# Out:
# Empty DataFrame
# Columns: [pclass, survived, name, sex, age, sibsp, parch, ticket, fare, cabin, embarked, boat, body, home.dest]
# Index: []

# %%
# since no rows appeared in the output, there are no duplicate rows in the "titanic" dataset...

# %% [markdown]
# ## B * O * N * U * S
#
# <b>17. Use the space below to write the code to answer the 4 questions you listed in question #2.</b>

# %%
## Question 1: how many people survived? how many died?

# use the "value_counts" method to discover how many people survived & died (look at "survived" method)...

titanic["survived"].value_counts()
# Out:
# 0    809
# 1    500
# Name: survived, dtype: int64

# %%
# with the value of "0" (did not survive): 809 people...
# with the value of "1" (survived): 500 people...

# %%
## Question 2: from the people that survived & died, from which passenger class?

# use the "crosstab" method to discover the number of passengers that survived or died (look at "survived" column) 
# by passenger class (look at "pclass" column)...

pd.crosstab(titanic["survived"], titanic["pclass"], margins=True)
# Out:
# pclass      1    2    3   All
# survived
# 0         123  158  528   809
# 1         200  119  181   500
# All       323  277  709  1309

# %%
# from passenger class 1: 
# "survived" value of "0" (did not survive): 123
# "survived" value of "1" (survived): 200

# from passenger class 2: 
# "survived" value of "0" (did not survive): 158
# "survived" value of "1" (survived): 119

# from passenger class 3: 
# "survived" value of "0" (did not survive): 528
# "survived" value of "1" (survived): 181

# %%
## Question 3: from the people that survived & died, from where they embarked?

# use the "crosstab" method to discover the number of passengers that survived or died (look at "survived" column) 
# by boarding port (look at "embarked" column)...
#C = Cherbourg, Q = Queenstown, S = Southampton

pd.crosstab(titanic["survived"], titanic["embarked"], margins=True)
# Out:
# embarked    C    Q    S   All
# survived
# 0         120   79  610   809
# 1         150   44  304   498
# All       270  123  914  1307

# %%
# from boarding in Cherbourg ("C"): 
# "survived" value of "0" (did not survive): 120
# "survived" value of "1" (survived): 150

# from boarding in Queenstown ("Q"): 
# "survived" value of "0" (did not survive): 79
# "survived" value of "1" (survived): 44

# from boarding in Southhampton ("S"):
# "survived" value of "0" (did not survive): 610
# "survived" value of "1" (survived): 304

# %%
## Question 4: from the people that survived & died, the breakdown by sex?

# use the "crosstab" method to discover the number of passengers that survived or died (look at "survived" column) 
# by sex (look at "sex" column)...

pd.crosstab(titanic["survived"], titanic["sex"], margins=True)
# Out:
# sex       female  male   All
# survived
# 0            127   682   809
# 1            339   161   500
# All          466   843  1309

# %%
# by male: 
# "survived" value of "0" (did not survive): 682
# "survived" value of "1" (survived): 161

# by female: 
# "survived" value of "0" (did not survive): 127
# "survived" value of "1" (survived): 339

# %% [markdown]
# # Well Done!!
